# %%
##The feature engineering was redone starting from the original work and with extra work by us.

# %%
#updates:
#applied imputation into numerical and categorical data to improve the score by 0.327, now 0.9194



import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy import stats
from plotly.offline import iplot, init_notebook_mode

init_notebook_mode(connected=True)

# Preprocessing, modelling and evaluating
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold

import gc
import os 

#print where those datasets are located 
from sklearn.preprocessing import minmax_scale
# from sklearn.cluster import KMeans

## Function to reduce the DF size
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df


#df_trans = pd.read_csv('train_transaction.csv')
df_trans = pd.read_csv('train_transaction.csv',index_col='TransactionID')
df_test_trans = pd.read_csv('test_transaction.csv',index_col='TransactionID')

#record index of test datasets
test_trans_id = df_test_trans.index

#df_id = pd.read_csv('train_identity.csv')
df_id = pd.read_csv('train_identity.csv',index_col='TransactionID')
df_test_id = pd.read_csv('test_identity.csv',index_col='TransactionID')




sample_submission = pd.read_csv('sample_submission.csv', index_col='TransactionID')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def id_split(dataframe):
    
    #expand = split and expand to seperate column
    dataframe['device_name'] = dataframe['DeviceInfo'].str.split('/', expand=True)[0]
    dataframe['device_version'] = dataframe['DeviceInfo'].str.split('/', expand=True)[1]

    dataframe['OS_id_30'] = dataframe['id_30'].str.split(' ', expand=True)[0]
    dataframe['version_id_30'] = dataframe['id_30'].str.split(' ', expand=True)[1]

    dataframe['browser_id_31'] = dataframe['id_31'].str.split(' ', expand=True)[0]
    dataframe['version_id_31'] = dataframe['id_31'].str.split(' ', expand=True)[1]

    dataframe['screen_width'] = dataframe['id_33'].str.split('x', expand=True)[0]
    dataframe['screen_height'] = dataframe['id_33'].str.split('x', expand=True)[1]

    dataframe['id_34'] = dataframe['id_34'].str.split(':', expand=True)[1]
    dataframe['id_23'] = dataframe['id_23'].str.split(':', expand=True)[1]
    
    #very specifically group device brands to help making decision
    dataframe.loc[dataframe['device_name'].str.contains('SM', na=False), 'device_name'] = 'Samsung'
    dataframe.loc[dataframe['device_name'].str.contains('SAMSUNG', na=False), 'device_name'] = 'Samsung'
    dataframe.loc[dataframe['device_name'].str.contains('GT-', na=False), 'device_name'] = 'Samsung'
    dataframe.loc[dataframe['device_name'].str.contains('Moto G', na=False), 'device_name'] = 'Motorola'
    dataframe.loc[dataframe['device_name'].str.contains('Moto', na=False), 'device_name'] = 'Motorola'
    dataframe.loc[dataframe['device_name'].str.contains('moto', na=False), 'device_name'] = 'Motorola'
    dataframe.loc[dataframe['device_name'].str.contains('LG-', na=False), 'device_name'] = 'LG'
    dataframe.loc[dataframe['device_name'].str.contains('rv:', na=False), 'device_name'] = 'RV'
    dataframe.loc[dataframe['device_name'].str.contains('HUAWEI', na=False), 'device_name'] = 'Huawei'
    dataframe.loc[dataframe['device_name'].str.contains('ALE-', na=False), 'device_name'] = 'Huawei'
    dataframe.loc[dataframe['device_name'].str.contains('-L', na=False), 'device_name'] = 'Huawei'
    dataframe.loc[dataframe['device_name'].str.contains('Blade', na=False), 'device_name'] = 'ZTE'
    dataframe.loc[dataframe['device_name'].str.contains('BLADE', na=False), 'device_name'] = 'ZTE'
    dataframe.loc[dataframe['device_name'].str.contains('Linux', na=False), 'device_name'] = 'Linux'
    dataframe.loc[dataframe['device_name'].str.contains('XT', na=False), 'device_name'] = 'Sony'
    dataframe.loc[dataframe['device_name'].str.contains('HTC', na=False), 'device_name'] = 'HTC'
    dataframe.loc[dataframe['device_name'].str.contains('ASUS', na=False), 'device_name'] = 'Asus'

    #make the device name that are less than 200 to be other
    dataframe.loc[dataframe.device_name.isin(dataframe.device_name.value_counts()[dataframe.device_name.value_counts() < 200].index), 'device_name'] = "Others"
    
    #new column to record that this device has id???
    dataframe['had_id'] = 1
    gc.collect()
    
    return dataframe

# %%
df_trans[df_trans['V326']==0]['isFraud']
# Out:
# TransactionID
# 2987004    0
# 2987008    0
# 2987016    0
# 2987017    0
# 2987022    0
#           ..
# 3577465    0
# 3577495    0
# 3577506    0
# 3577526    1
# 3577531    0
# Name: isFraud, Length: 72668, dtype: int64

# %%
#C sum feature
df_trans["C_sum"] = df_trans.loc[:,'C1':'C14'].sum(axis = 1).astype(np.int8)
df_test_trans["C_sum"] = df_test_trans.loc[:,'C1':'C14'].sum(axis = 1).astype(np.int8)

    
##D1 - D15
df_trans['D_na'] =df_trans.loc[:,'D1':'D14'].isna().sum(axis=1).astype(np.int8)
df_test_trans['D_na'] =df_test_trans.loc[:,'D1':'D14'].isna().sum(axis=1).astype(np.int8)

    
##M1-9
i_cols = ['M1','M2','M3','M5','M6','M7','M8','M9']

df_trans['M_na'] = df_trans[i_cols].isna().sum(axis=1).astype(np.int8)
df_test_trans['M_na'] = df_test_trans[i_cols].isna().sum(axis=1).astype(np.int8)


    
##V_ features
df_trans['V_na'] =df_trans.loc[:,"V1":"V339"].isna().sum(axis=1).astype(np.int8)
df_test_trans['V_na'] =df_test_trans.loc[:,"V1":"V339"].isna().sum(axis=1).astype(np.int8)

##ids 
df_id['id_na'] = df_id.loc[:,"id_01":"id_38"].isna().sum(axis=1).astype(np.int8)
df_test_id['id_na'] = df_test_id.loc[:,"id_01":"id_38"].isna().sum(axis=1).astype(np.int8)

# %%
df_id = id_split(df_id)
df_test_id = id_split(df_test_id)

# %%
##do not need to include right_index
df_train = df_trans.merge(df_id, how='left', left_index=True,  on='TransactionID')
df_test = df_test_trans.merge(df_test_id, how='left', left_index=True, on='TransactionID')

#add total na for train and test data. 
df_train['tot_na'] = df_train.isna().sum(axis=1).astype(np.int8) 
df_test['tot_na'] = df_test.isna().sum(axis=1).astype(np.int8)

print(df_train.head())
print(df_test.head())


# y_train = df_train['isFraud'].copy()
del df_trans, df_id, df_test_trans, df_test_id
gc.collect()



df_train = reduce_mem_usage(df_train)
df_test = reduce_mem_usage(df_test)
##Deal with missing data
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000              0          86400            68.5         W  13926    NaN
# 2987001              0          86401            29.0         W   2755  404.0
# 2987002              0          86469            59.0         W   4663  490.0
# 2987003              0          86499            50.0         W  18132  567.0
# 2987004              0          86506            50.0         H   4497  514.0
#
#                card3       card4  card5   card6  ...  device_name  \
# TransactionID                                    ...
# 2987000        150.0    discover  142.0  credit  ...          NaN
# 2987001        150.0  mastercard  102.0  credit  ...          NaN
# 2987002        150.0        visa  166.0   debit  ...          NaN
# 2987003        150.0  mastercard  117.0   debit  ...          NaN
# 2987004        150.0  mastercard  102.0  credit  ...      Samsung
#
#                device_version  OS_id_30  version_id_30 browser_id_31  \
# TransactionID
# 2987000                   NaN       NaN            NaN           NaN
# 2987001                   NaN       NaN            NaN           NaN
# 2987002                   NaN       NaN            NaN           NaN
# 2987003                   NaN       NaN            NaN           NaN
# 2987004                NRD90M   Android            7.0       samsung
#
#               version_id_31  screen_width  screen_height  had_id  tot_na
# TransactionID
# 2987000                 NaN           NaN            NaN     NaN     -12
# 2987001                 NaN           NaN            NaN     NaN     -16
# 2987002                 NaN           NaN            NaN     NaN     -35
# 2987003                 NaN           NaN            NaN     NaN     -19
# 2987004             browser          2220           1080     1.0    -119
#
# [5 rows x 448 columns]
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 3663549             18403224           31.95         W  10409  111.0  150.0
# 3663550             18403263           49.00         W   4272  111.0  150.0
# 3663551             18403310          171.00         W   4476  574.0  150.0
# 3663552             18403310          284.95         W  10989  360.0  150.0
# 3663553             18403317           67.95         W  18018  452.0  150.0
#
#                     card4  card5  card6  addr1  ...  device_name  \
# TransactionID                                   ...
# 3663549              visa  226.0  debit  170.0  ...          NaN
# 3663550              visa  226.0  debit  299.0  ...          NaN
# 3663551              visa  226.0  debit  472.0  ...          NaN
# 3663552              visa  166.0  debit  205.0  ...          NaN
# 3663553        mastercard  117.0  debit  264.0  ...          NaN
#
#                device_version  OS_id_30 version_id_30 browser_id_31  \
# TransactionID
# 3663549                   NaN       NaN           NaN           NaN
# 3663550                   NaN       NaN           NaN           NaN
# 3663551                   NaN       NaN           NaN           NaN
# 3663552                   NaN       NaN           NaN           NaN
# 3663553                   NaN       NaN           NaN           NaN
#
#                version_id_31  screen_width  screen_height  had_id  tot_na
# TransactionID
# 3663549                  NaN           NaN            NaN     NaN     -36
# 3663550                  NaN           NaN            NaN     NaN     -34
# 3663551                  NaN           NaN            NaN     NaN     -38
# 3663552                  NaN           NaN            NaN     NaN     -33
# 3663553                  NaN           NaN            NaN     NaN     -36
#
# [5 rows x 447 columns]
# Mem. usage decreased to 689.34 Mb (65.6% reduction)
# Mem. usage decreased to 598.71 Mb (65.1% reduction)

# %%
df_train.loc[3577531,"screen_height"]
# Out:
# '1600'

# %%
#https://www.kaggle.com/davidcairuz/feature-engineering-lightgbm#
#removed V300 feature
useful_features = ['TransactionDT','TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2', 'dist1',
                   'P_emaildomain', 'R_emaildomain', 'C1', 'C2', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13',
                   'C14', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D8', 'D9', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'M2', 'M3',
                   'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V17',
                   'V19', 'V20', 'V29', 'V30', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V40', 'V44', 'V45', 'V46', 'V47', 'V48',
                   'V49', 'V51', 'V52', 'V53', 'V54', 'V56', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63', 'V64', 'V69', 'V70', 'V71',
                   'V72', 'V73', 'V74', 'V75', 'V76', 'V78', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V87', 'V90', 'V91', 'V92',
                   'V93', 'V94', 'V95', 'V96', 'V97', 'V99', 'V100', 'V126', 'V127', 'V128', 'V130', 'V131', 'V138', 'V139', 'V140',
                   'V143', 'V145', 'V146', 'V147', 'V149', 'V150', 'V151', 'V152', 'V154', 'V156', 'V158', 'V159', 'V160', 'V161',
                   'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V169', 'V170', 'V171', 'V172', 'V173', 'V175', 'V176', 'V177',
                   'V178', 'V180', 'V182', 'V184', 'V187', 'V188', 'V189', 'V195', 'V197', 'V200', 'V201', 'V202', 'V203', 'V204',
                   'V205', 'V206', 'V207', 'V208', 'V209', 'V210', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V219', 'V220',
                   'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V231', 'V233', 'V234', 'V238', 'V239',
                   'V242', 'V243', 'V244', 'V245', 'V246', 'V247', 'V249', 'V251', 'V253', 'V256', 'V257', 'V258', 'V259', 'V261',
                   'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275', 'V276',
                   'V277', 'V278', 'V279', 'V280', 'V282', 'V283', 'V285', 'V287', 'V288', 'V289', 'V291', 'V292', 'V294','id_01',
                   'id_02', 'id_03', 'id_05', 'id_06', 'id_09',
                   'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_17', 'id_19', 'id_20', 'id_30', 'id_31', 'id_32', 'id_33',
                   'id_36', 'id_37', 'id_38', 'DeviceType', 'DeviceInfo', 'device_name', 'device_version', 'OS_id_30', 'version_id_30',
                   'browser_id_31', 'version_id_31', 'screen_width', 'screen_height', 'had_id','tot_na','C_sum','D_na','M_na','V_na','id_na']
print(len(useful_features))
# Out:
# 273

# %%
cols_to_drop = [col for col in df_train.columns if col not in useful_features]
cols_to_drop.remove('isFraud')

# %%
df_train = df_train.drop(cols_to_drop, axis=1)
df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_train
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000              0          86400       68.500000         W  13926    NaN
# 2987001              0          86401       29.000000         W   2755  404.0
# 2987002              0          86469       59.000000         W   4663  490.0
# 2987003              0          86499       50.000000         W  18132  567.0
# 2987004              0          86506       50.000000         H   4497  514.0
# ...                ...            ...             ...       ...    ...    ...
# 3577535              0       15811047       49.000000         W   6550    NaN
# 3577536              0       15811049       39.500000         W  10444  225.0
# 3577537              0       15811079       30.953125         W  12037  595.0
# 3577538              0       15811088      117.000000         W   7826  481.0
# 3577539              0       15811131      280.000000         W  15066  170.0
#
#                card3       card4  card5   card6  ...  device_name  \
# TransactionID                                    ...
# 2987000        150.0    discover  142.0  credit  ...          NaN
# 2987001        150.0  mastercard  102.0  credit  ...          NaN
# 2987002        150.0        visa  166.0   debit  ...          NaN
# 2987003        150.0  mastercard  117.0   debit  ...          NaN
# 2987004        150.0  mastercard  102.0  credit  ...      Samsung
# ...              ...         ...    ...     ...  ...          ...
# 3577535        150.0        visa  226.0   debit  ...          NaN
# 3577536        150.0  mastercard  224.0   debit  ...          NaN
# 3577537        150.0  mastercard  224.0   debit  ...          NaN
# 3577538        150.0  mastercard  224.0   debit  ...          NaN
# 3577539        150.0  mastercard  102.0  credit  ...          NaN
#
#                device_version  OS_id_30 version_id_30 browser_id_31  \
# TransactionID
# 2987000                   NaN       NaN           NaN           NaN
# 2987001                   NaN       NaN           NaN           NaN
# 2987002                   NaN       NaN           NaN           NaN
# 2987003                   NaN       NaN           NaN           NaN
# 2987004                NRD90M   Android           7.0       samsung
# ...                       ...       ...           ...           ...
# 3577535                   NaN       NaN           NaN           NaN
# 3577536                   NaN       NaN           NaN           NaN
# 3577537                   NaN       NaN           NaN           NaN
# 3577538                   NaN       NaN           NaN           NaN
# 3577539                   NaN       NaN           NaN           NaN
#
#                version_id_31  screen_width  screen_height  had_id  tot_na
# TransactionID
# 2987000                  NaN           NaN            NaN     NaN     -12
# 2987001                  NaN           NaN            NaN     NaN     -16
# 2987002                  NaN           NaN            NaN     NaN     -35
# 2987003                  NaN           NaN            NaN     NaN     -19
# 2987004              browser          2220           1080     1.0    -119
# ...                      ...           ...            ...     ...     ...
# 3577535                  NaN           NaN            NaN     NaN     -16
# 3577536                  NaN           NaN            NaN     NaN     -34
# 3577537                  NaN           NaN            NaN     NaN     -29
# 3577538                  NaN           NaN            NaN     NaN     -35
# 3577539                  NaN           NaN            NaN     NaN     -34
#
# [590540 rows x 274 columns]

# %%
print(df_train)
print(df_test)
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000              0          86400       68.500000         W  13926    NaN
# 2987001              0          86401       29.000000         W   2755  404.0
# 2987002              0          86469       59.000000         W   4663  490.0
# 2987003              0          86499       50.000000         W  18132  567.0
# 2987004              0          86506       50.000000         H   4497  514.0
# ...                ...            ...             ...       ...    ...    ...
# 3577535              0       15811047       49.000000         W   6550    NaN
# 3577536              0       15811049       39.500000         W  10444  225.0
# 3577537              0       15811079       30.953125         W  12037  595.0
# 3577538              0       15811088      117.000000         W   7826  481.0
# 3577539              0       15811131      280.000000         W  15066  170.0
#
#                card3       card4  card5   card6  ...  device_name  \
# TransactionID                                    ...
# 2987000        150.0    discover  142.0  credit  ...          NaN
# 2987001        150.0  mastercard  102.0  credit  ...          NaN
# 2987002        150.0        visa  166.0   debit  ...          NaN
# 2987003        150.0  mastercard  117.0   debit  ...          NaN
# 2987004        150.0  mastercard  102.0  credit  ...      Samsung
# ...              ...         ...    ...     ...  ...          ...
# 3577535        150.0        visa  226.0   debit  ...          NaN
# 3577536        150.0  mastercard  224.0   debit  ...          NaN
# 3577537        150.0  mastercard  224.0   debit  ...          NaN
# 3577538        150.0  mastercard  224.0   debit  ...          NaN
# 3577539        150.0  mastercard  102.0  credit  ...          NaN
#
#                device_version  OS_id_30 version_id_30 browser_id_31  \
# TransactionID
# 2987000                   NaN       NaN           NaN           NaN
# 2987001                   NaN       NaN           NaN           NaN
# 2987002                   NaN       NaN           NaN           NaN
# 2987003                   NaN       NaN           NaN           NaN
# 2987004                NRD90M   Android           7.0       samsung
# ...                       ...       ...           ...           ...
# 3577535                   NaN       NaN           NaN           NaN
# 3577536                   NaN       NaN           NaN           NaN
# 3577537                   NaN       NaN           NaN           NaN
# 3577538                   NaN       NaN           NaN           NaN
# 3577539                   NaN       NaN           NaN           NaN
#
#                version_id_31  screen_width  screen_height  had_id  tot_na
# TransactionID
# 2987000                  NaN           NaN            NaN     NaN     -12
# 2987001                  NaN           NaN            NaN     NaN     -16
# 2987002                  NaN           NaN            NaN     NaN     -35
# 2987003                  NaN           NaN            NaN     NaN     -19
# 2987004              browser          2220           1080     1.0    -119
# ...                      ...           ...            ...     ...     ...
# 3577535                  NaN           NaN            NaN     NaN     -16
# 3577536                  NaN           NaN            NaN     NaN     -34
# 3577537                  NaN           NaN            NaN     NaN     -29
# 3577538                  NaN           NaN            NaN     NaN     -35
# 3577539                  NaN           NaN            NaN     NaN     -34
#
# [590540 rows x 274 columns]
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 3663549             18403224       31.953125         W  10409  111.0  150.0
# 3663550             18403263       49.000000         W   4272  111.0  150.0
# 3663551             18403310      171.000000         W   4476  574.0  150.0
# 3663552             18403310      285.000000         W  10989  360.0  150.0
# 3663553             18403317       67.937500         W  18018  452.0  150.0
# ...                      ...             ...       ...    ...    ...    ...
# 4170235             34214279       94.687500         C  13832  375.0  185.0
# 4170236             34214287       12.171875         C   3154  408.0  185.0
# 4170237             34214326       49.000000         W  16661  490.0  150.0
# 4170238             34214337      202.000000         W  16621  516.0  150.0
# 4170239             34214345       24.343750         C   5713  168.0  144.0
#
#                     card4  card5   card6  addr1  ...  device_name  \
# TransactionID                                    ...
# 3663549              visa  226.0   debit  170.0  ...          NaN
# 3663550              visa  226.0   debit  299.0  ...          NaN
# 3663551              visa  226.0   debit  472.0  ...          NaN
# 3663552              visa  166.0   debit  205.0  ...          NaN
# 3663553        mastercard  117.0   debit  264.0  ...          NaN
# ...                   ...    ...     ...    ...  ...          ...
# 4170235        mastercard  224.0   debit  284.0  ...          NaN
# 4170236        mastercard  224.0   debit    NaN  ...       Huawei
# 4170237              visa  226.0   debit  327.0  ...          NaN
# 4170238        mastercard  224.0   debit  177.0  ...          NaN
# 4170239              visa  147.0  credit    NaN  ...      Samsung
#
#                device_version OS_id_30 version_id_30  browser_id_31  \
# TransactionID
# 3663549                   NaN      NaN           NaN            NaN
# 3663550                   NaN      NaN           NaN            NaN
# 3663551                   NaN      NaN           NaN            NaN
# 3663552                   NaN      NaN           NaN            NaN
# 3663553                   NaN      NaN           NaN            NaN
# ...                       ...      ...           ...            ...
# 4170235                   NaN      NaN           NaN            NaN
# 4170236         HuaweiALE-L23      NaN           NaN         chrome
# 4170237                   NaN      NaN           NaN            NaN
# 4170238                   NaN      NaN           NaN            NaN
# 4170239                  None      NaN           NaN        samsung
#
#                version_id_31  screen_width  screen_height  had_id  tot_na
# TransactionID
# 3663549                  NaN           NaN            NaN     NaN     -36
# 3663550                  NaN           NaN            NaN     NaN     -34
# 3663551                  NaN           NaN            NaN     NaN     -38
# 3663552                  NaN           NaN            NaN     NaN     -33
# 3663553                  NaN           NaN            NaN     NaN     -36
# ...                      ...           ...            ...     ...     ...
# 4170235                  NaN           NaN            NaN     NaN     -17
# 4170236                 43.0           NaN            NaN     1.0      94
# 4170237                  NaN           NaN            NaN     NaN     -34
# 4170238                  NaN           NaN            NaN     NaN     -34
# 4170239              browser           NaN            NaN     1.0      95
#
# [506691 rows x 273 columns]

# %%
#new feature regarding TransactionDT
# any repeated transation consecutively under one card1 number is very suspicious. 
df_train= df_train.sort_values(by =['card1','TransactionDT'])

rpt_trans = [1  if df_train.iloc[i,2] == df_train.iloc[i+1,2] or df_train.iloc[i,2] == df_train.iloc[i-1,2] else 0 for i in range(1,df_train.shape[0]-1)]
df_train['rept_trans'] =[0]+ rpt_trans +[0]

df_test= df_test.sort_values(by =['card1','TransactionDT'])

rpt_trans = [1  if df_test.iloc[i,2] == df_test.iloc[i+1,2] or df_test.iloc[i,2] == df_test.iloc[i-1,2] else 0 for i in range(1,df_test.shape[0]-1)]
df_test['rept_trans'] =[0]+ rpt_trans +[0]

# %%
#added card6 - debit credit
columns_a = ['TransactionAmt', 'id_02', 'D15']
columns_b = ['card1', 'card2']

for col_a in columns_a:
    for col_b in columns_b:
        for df in [df_train, df_test]:
            df[f'{col_a}_to_mean_{col_b}'] = df[col_a] / df.groupby([col_b])[col_a].transform('mean')
            df[f'{col_a}_to_std_{col_b}'] = df[col_a] / df.groupby([col_b])[col_a].transform('std')

# %%
# New feature - log of transaction amount.
df_train['TransactionAmt_Log'] = np.log(df_train['TransactionAmt'])
df_test['TransactionAmt_Log'] = np.log(df_test['TransactionAmt'])

# New feature - decimal part of the transaction amount.
df_train['TransactionAmt_decimal'] = ((df_train['TransactionAmt'] - df_train['TransactionAmt'].astype(int)) * 1000).astype(int)
df_test['TransactionAmt_decimal'] = ((df_test['TransactionAmt'] - df_test['TransactionAmt'].astype(int)) * 1000).astype(int)

# New feature - day of week in which a transaction happened.
df_train['Transaction_day_of_week'] = np.floor((df_train['TransactionDT'] / (3600 * 24) - 1) % 7)
df_test['Transaction_day_of_week'] = np.floor((df_test['TransactionDT'] / (3600 * 24) - 1) % 7)

# New feature - hour of the day in which a transaction happened.
df_train['Transaction_hour'] = np.floor(df_train['TransactionDT'] / 3600) % 24
df_test['Transaction_hour'] = np.floor(df_test['TransactionDT'] / 3600) % 24

# Some arbitrary features interaction
for feature in ['id_02__id_20', 'id_02__D8', 'D11__DeviceInfo', 'DeviceInfo__P_emaildomain',
                'card2__dist1', 'card1__card5', 'card2__id_20', 'card1__P_emaildomain', 'addr1__card1']:

    f1, f2 = feature.split('__')
    df_train[feature] = df_train[f1].astype(str) + '_' + df_train[f2].astype(str)
    df_test[feature] = df_test[f1].astype(str) + '_' + df_test[f2].astype(str)

    le = preprocessing.LabelEncoder()
    le.fit(list(df_train[feature].astype(str).values) + list(df_test[feature].astype(str).values))
    df_train[feature] = le.transform(list(df_train[feature].astype(str).values))
    df_test[feature] = le.transform(list(df_test[feature].astype(str).values))

# Encoding - count encoding for both df_train and df_test
for feature in ['card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'id_36']:
    df_train[feature + '_count_full'] = df_train[feature].map(pd.concat([df_train[feature], df_test[feature]], ignore_index=True).value_counts(dropna=False))
    df_test[feature + '_count_full'] = df_test[feature].map(pd.concat([df_train[feature], df_test[feature]], ignore_index=True).value_counts(dropna=False))

# Encoding - count encoding separately for df_train and df_test
for feature in ['id_01', 'id_31', 'id_33', 'id_36']:
    df_train[feature + '_count_dist'] = df_train[feature].map(df_train[feature].value_counts(dropna=False))
    df_test[feature + '_count_dist'] = df_test[feature].map(df_test[feature].value_counts(dropna=False))

# %%
df_train = df_train.reset_index()
df_train
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             3230924        0        5787419         23.4375         C
# 1             3023634        0         916268        183.0000         W
# 2             3151336        0        3504180         29.0000         W
# 3             3210739        0        5270458         27.0000         W
# 4             3020767        0         842821        150.0000         R
# ...               ...      ...            ...             ...       ...
# 590535        3419314        0       10938204        232.5000         W
# 590536        3420746        0       10964952         36.9375         W
# 590537        3446622        0       11806909         36.9375         W
# 590538        3480204        0       12865537         36.9375         W
# 590539        3102181        0        2231501        100.0000         R
#
#         card1  card2  card3       card4  card5  ... card2_count_full  \
# 0        1000  555.0  185.0  mastercard  224.0  ...            80404
# 1        1001  555.0  150.0        visa  226.0  ...            80404
# 2        1001  555.0  150.0        visa  226.0  ...            80404
# 3        1001  555.0  150.0        visa  226.0  ...            80404
# 4        1004  583.0  150.0        visa  226.0  ...            41503
# ...       ...    ...    ...         ...    ...  ...              ...
# 590535  18395  543.0  150.0  mastercard  224.0  ...             9968
# 590536  18395  543.0  150.0  mastercard  224.0  ...             9968
# 590537  18395  543.0  150.0  mastercard  224.0  ...             9968
# 590538  18395  543.0  150.0  mastercard  224.0  ...             9968
# 590539  18396  111.0  150.0        visa  226.0  ...            82537
#
#         card3_count_full  card4_count_full  card5_count_full card6_count_full  \
# 0                 109960            347386            153109           824959
# 1                 956845            719649            553537           824959
# 2                 956845            719649            553537           824959
# 3                 956845            719649            553537           824959
# 4                 956845            719649            553537           267648
# ...                  ...               ...               ...              ...
# 590535            956845            347386            153109           824959
# 590536            956845            347386            153109           824959
# 590537            956845            347386            153109           824959
# 590538            956845            347386            153109           824959
# 590539            956845            719649            553537           824959
#
#        id_36_count_full  id_01_count_dist  id_31_count_dist  id_33_count_dist  \
# 0                267353             82170              5806            517251
# 1                819269            446307            450258            517251
# 2                819269            446307            450258            517251
# 3                819269            446307            450258            517251
# 4                267353             82170             22000               263
# ...                 ...               ...               ...               ...
# 590535           819269            446307            450258            517251
# 590536           819269            446307            450258            517251
# 590537           819269            446307            450258            517251
# 590538           819269            446307            450258            517251
# 590539           267353             82170              9030            517251
#
#         id_36_count_dist
# 0                 134066
# 1                 449555
# 2                 449555
# 3                 449555
# 4                 134066
# ...                  ...
# 590535            449555
# 590536            449555
# 590537            449555
# 590538            449555
# 590539            134066
#
# [590540 rows x 312 columns]

# %%
#k fold cross validation target mean coding to avoid overfitting

N_SPLITS = 5
SEED = 6

folds = KFold(n_splits=N_SPLITS,shuffle = False, random_state=SEED)
# Test Data and expport DF
  
score = 0
y_result = 0

mean_of_target = df_train['isFraud'].mean()

target_mean_list =['card1','card2','addr1','addr1__card1','card1__card5','card1__P_emaildomain']

# kfold target mean encoding for regularisation

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train)):
    print('Fold:',fold_+1)
    tr_x = df_train.iloc[trn_idx,:] 
    vl_x = df_train.iloc[val_idx,:]  
    
    for col in target_mean_list:
        print(col)
        df_train.loc[val_idx,f'{col}_target_enc'] = vl_x[col].map(tr_x.groupby(col)['isFraud'].mean())
        
        df_train[f'{col}_target_enc'].fillna(mean_of_target, inplace = True)
                                                        
for col in target_mean_list:
                                                            
    df_test[f'{col}_target_enc'] = df_test[col].map(df_train.groupby(col)[f'{col}_target_enc'].mean())

    df_test[f'{col}_target_enc'].fillna(mean_of_target, inplace = True)
# Out:
# Fold: 1
# card1
# card2
# addr1
# addr1__card1
# card1__card5
# card1__P_emaildomain
# Fold: 2
# card1
# card2
# addr1
# addr1__card1
# card1__card5
# card1__P_emaildomain
# Fold: 3
# card1
# card2
# addr1
# addr1__card1
# card1__card5
# card1__P_emaildomain
# Fold: 4
# card1
# card2
# addr1
# addr1__card1
# card1__card5
# card1__P_emaildomain
# Fold: 5
# card1
# card2
# addr1
# addr1__card1
# card1__card5
# card1__P_emaildomain

# %%
#label encoding the rest 
for col in df_train.columns:
    if df_train[col].dtype == 'object':
        le = preprocessing.LabelEncoder()
        le.fit(list(df_train[col].astype(str).values) + list(df_test[col].astype(str).values))
        df_train[col] = le.transform(list(df_train[col].astype(str).values))
        df_test[col] = le.transform(list(df_test[col].astype(str).values))

# %%
#why sort ??
X_train = df_train.sort_values('TransactionDT').drop(['isFraud', 'TransactionDT','TransactionID'], axis=1)
y_train = df_train.sort_values('TransactionDT')['isFraud']

X_test = df_test.drop(['TransactionDT'], axis=1)

del df_train, df_test
gc.collect()
# Out:
# 20

# %%
X_test
# Out:
#                TransactionAmt  ProductCD  card1  card2  card3  card4  card5  \
# TransactionID
# 4084529               50.0000          1   1001  555.0  150.0      4  226.0
# 4113026               39.0000          4   1001  555.0  150.0      4  226.0
# 4147003               60.0000          1   1002    NaN  150.0      2    NaN
# 3981622               42.9375          4   1003  452.0  150.0      2  224.0
# 4044940              100.0000          1   1004  583.0  150.0      4  226.0
# ...                       ...        ...    ...    ...    ...    ...    ...
# 4004795              117.0000          4  18396  111.0  150.0      4  226.0
# 4054400              226.0000          4  18396  111.0  150.0      4  226.0
# 4072739              226.0000          4  18396  111.0  150.0      4  226.0
# 4109100               39.0000          4  18396  111.0  150.0      4  226.0
# 3875101               40.6875          0  18397  555.0  121.0      4  102.0
#
#                card6  addr1  addr2  ...  id_01_count_dist  id_31_count_dist  \
# TransactionID                       ...
# 4084529            2  269.0   87.0  ...             82579             16054
# 4113026            2  269.0   87.0  ...            364784            370066
# 4147003            1  343.0   87.0  ...             82579             13098
# 3981622            2  264.0   87.0  ...            364784            370066
# 4044940            1  325.0   87.0  ...             12000               362
# ...              ...    ...    ...  ...               ...               ...
# 4004795            2  126.0   87.0  ...            364784            370066
# 4054400            2  126.0   87.0  ...            364784            370066
# 4072739            2  126.0   87.0  ...            364784            370066
# 4109100            2  126.0   87.0  ...            364784            370066
# 3875101            1    NaN    NaN  ...             11793              1107
#
#                id_33_count_dist  id_36_count_dist  card1_target_enc  \
# TransactionID
# 4084529                    6441            133287           0.03499
# 4113026                  436020            369714           0.03499
# 4147003                    2746            133287           0.03499
# 3981622                  436020            369714           0.03499
# 4044940                    1555              3690           0.03499
# ...                         ...               ...               ...
# 4004795                  436020            369714           0.03499
# 4054400                  436020            369714           0.03499
# 4072739                  436020            369714           0.03499
# 4109100                  436020            369714           0.03499
# 3875101                  436020            133287           0.03499
#
#                card2_target_enc  addr1_target_enc  addr1__card1_target_enc  \
# TransactionID
# 4084529                0.022705          0.035629                  0.03499
# 4113026                0.022705          0.035629                  0.03499
# 4147003                0.034990          0.017703                  0.03499
# 3981622                0.000650          0.018267                  0.03499
# 4044940                0.041566          0.025488                  0.03499
# ...                         ...               ...                      ...
# 4004795                0.021892          0.025796                  0.03499
# 4054400                0.021892          0.025796                  0.03499
# 4072739                0.021892          0.025796                  0.03499
# 4109100                0.021892          0.025796                  0.03499
# 3875101                0.022705          0.034990                  0.03499
#
#                card1__card5_target_enc  card1__P_emaildomain_target_enc
# TransactionID
# 4084529                        0.03499                          0.03499
# 4113026                        0.03499                          0.03499
# 4147003                        0.03499                          0.03499
# 3981622                        0.03499                          0.03499
# 4044940                        0.03499                          0.03499
# ...                                ...                              ...
# 4004795                        0.03499                          0.03499
# 4054400                        0.03499                          0.03499
# 4072739                        0.03499                          0.03499
# 4109100                        0.03499                          0.03499
# 3875101                        0.03499                          0.03499
#
# [506691 rows x 315 columns]

# %%
from sklearn.model_selection import KFold
import lightgbm as lgb
##The following will carry out automated parameters optimisation for mainly accuray and overfitting related parameters based on Bayesian optimisation
from sklearn.model_selection import KFold, train_test_split
from sklearn import metrics

# %%
##Those parameters are the optimised ones for 4 hours 
#small min_data, large min_leaves, small learning rate, gbdt. 
#https://www.kaggle.com/kyakovlev/ieee-gb-2-make-amount-useful-again
best_param = {
                    'objective':'binary',
                    'boosting_type':'gbdt',
                    'metric':'auc',
                    'n_jobs':-1,
                    'learning_rate':0.01,
                    'num_leaves': 2**9,
                    'max_depth':-1,
                    'tree_learner':'serial',
                    'colsample_bytree': 0.7,
                    'subsample_freq':1,
                    'subsample':0.7,
                    'max_bin':500,
                    'verbose':-1,
                    'seed': SEED,
                    'early_stopping_rounds':100, 
                }

# %%
sum(X_train['rept_trans'])
# Out:
# 118712

# %%
N_SPLITS = 5
SEED = 6

columns = X_train.columns
feature_importances = pd.DataFrame()
feature_importances['feature'] = columns

folds = KFold(n_splits=N_SPLITS, random_state=SEED)
# Test Data and expport DF
  
y_preds = np.zeros(X_test.shape[0])
y_oof = np.zeros(X_train.shape[0])

score = 0
y_result = 0
print("running")
# use stratified fold to ensure the split datasets have same portion of postive and negative data.
for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train, y_train)):
    print('Fold:',fold_+1)
    tr_x, tr_y = X_train.iloc[trn_idx,:], y_train.iloc[trn_idx]    
    vl_x, v_y = X_train.iloc[val_idx,:], y_train.iloc[val_idx]    
    train_data = lgb.Dataset(tr_x, label=tr_y)
    valid_data = lgb.Dataset(vl_x, label=v_y)  
        
    #this will run very slow. 
    num_round =5000
        
    #here valid sets are the criteria for stopping, when the auc score for valid sets do not improve after num_round, then it will stop. 
    estimator = lgb.train(
            best_param,
            train_data, 
            num_round,
            valid_sets = [train_data,valid_data],
            #print evaluation at each step
            verbose_eval = 10,
            )

    y_pred_valid = estimator.predict(vl_x)
    y_oof[val_idx] = y_pred_valid
    print(f"Fold {fold_ + 1} | AUC: {roc_auc_score(v_y, y_pred_valid)}")
    
    #score is the roc_auc of valid pred 
    score += roc_auc_score(v_y, y_pred_valid) / N_SPLITS
    y_result += estimator.predict(X_test) / N_SPLITS
    # we are not sure what fold is best for us
    # so we will average prediction results 
    # over folds; meaning each fold we predict test data and then get average.
    
    feature_importances[f'fold_{fold_ + 1}'] = estimator.feature_importance()

    del train_data, valid_data
    gc.collect()
print(f"\nMean AUC = {score}")
print(f"Out of folds AUC = {roc_auc_score(y_train, y_oof)}")
    #print('LOG loss', metrics.log_loss(RESULTS['isFraud'], RESULTS['stratifiedkfold']))
# Out:
# running
# Fold: 1
# c:\users\oem\appdata\local\programs\python\python37\lib\site-packages\lightgbm\engine.py:123: UserWarning:
#
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.91547	valid_1's auc: 0.861272
# [20]	training's auc: 0.921847	valid_1's auc: 0.866578
# [30]	training's auc: 0.927352	valid_1's auc: 0.870485
# [40]	training's auc: 0.932956	valid_1's auc: 0.874441
# [50]	training's auc: 0.938095	valid_1's auc: 0.877661
# [60]	training's auc: 0.944165	valid_1's auc: 0.880653
# [70]	training's auc: 0.947993	valid_1's auc: 0.882864
# [80]	training's auc: 0.951503	valid_1's auc: 0.884606
# [90]	training's auc: 0.955123	valid_1's auc: 0.886747
# [100]	training's auc: 0.95816	valid_1's auc: 0.889135
# [110]	training's auc: 0.960793	valid_1's auc: 0.890718
# [120]	training's auc: 0.963919	valid_1's auc: 0.892611
# [130]	training's auc: 0.966834	valid_1's auc: 0.89388
# [140]	training's auc: 0.969196	valid_1's auc: 0.895271
# [150]	training's auc: 0.97152	valid_1's auc: 0.896194
# [160]	training's auc: 0.973969	valid_1's auc: 0.897288
# [170]	training's auc: 0.975677	valid_1's auc: 0.897977
# [180]	training's auc: 0.977336	valid_1's auc: 0.898951
# [190]	training's auc: 0.979323	valid_1's auc: 0.899786
# [200]	training's auc: 0.981472	valid_1's auc: 0.900897
# [210]	training's auc: 0.983399	valid_1's auc: 0.902077
# [220]	training's auc: 0.985154	valid_1's auc: 0.903024
# [230]	training's auc: 0.986624	valid_1's auc: 0.904061
# [240]	training's auc: 0.988035	valid_1's auc: 0.904698
# [250]	training's auc: 0.989239	valid_1's auc: 0.905578
# [260]	training's auc: 0.990279	valid_1's auc: 0.906302
# [270]	training's auc: 0.991157	valid_1's auc: 0.906929
# [280]	training's auc: 0.991945	valid_1's auc: 0.907507
# [290]	training's auc: 0.99276	valid_1's auc: 0.908134
# [300]	training's auc: 0.993568	valid_1's auc: 0.908711
# [310]	training's auc: 0.994195	valid_1's auc: 0.909216
# [320]	training's auc: 0.994733	valid_1's auc: 0.909667
# [330]	training's auc: 0.995244	valid_1's auc: 0.910541
# [340]	training's auc: 0.995706	valid_1's auc: 0.911145
# [350]	training's auc: 0.996108	valid_1's auc: 0.911516
# [360]	training's auc: 0.99647	valid_1's auc: 0.912049
# [370]	training's auc: 0.996793	valid_1's auc: 0.912609
# [380]	training's auc: 0.997111	valid_1's auc: 0.913077
# [390]	training's auc: 0.997392	valid_1's auc: 0.913591
# [400]	training's auc: 0.997633	valid_1's auc: 0.913905
# [410]	training's auc: 0.997873	valid_1's auc: 0.914256
# [420]	training's auc: 0.998071	valid_1's auc: 0.914493
# [430]	training's auc: 0.998266	valid_1's auc: 0.914911
# [440]	training's auc: 0.998429	valid_1's auc: 0.915303
# [450]	training's auc: 0.998594	valid_1's auc: 0.915671
# [460]	training's auc: 0.998729	valid_1's auc: 0.916031
# [470]	training's auc: 0.998853	valid_1's auc: 0.916462
# [480]	training's auc: 0.99896	valid_1's auc: 0.916773
# [490]	training's auc: 0.999068	valid_1's auc: 0.917076
# [500]	training's auc: 0.999161	valid_1's auc: 0.917296
# [510]	training's auc: 0.999244	valid_1's auc: 0.917574
# [520]	training's auc: 0.999312	valid_1's auc: 0.917881
# [530]	training's auc: 0.999383	valid_1's auc: 0.918082
# [540]	training's auc: 0.999446	valid_1's auc: 0.918098
# [550]	training's auc: 0.999497	valid_1's auc: 0.918276
# [560]	training's auc: 0.999545	valid_1's auc: 0.918334
# [570]	training's auc: 0.99959	valid_1's auc: 0.918415
# [580]	training's auc: 0.99963	valid_1's auc: 0.918576
# [590]	training's auc: 0.999669	valid_1's auc: 0.918775
# [600]	training's auc: 0.999703	valid_1's auc: 0.918901
# [610]	training's auc: 0.999732	valid_1's auc: 0.919008
# [620]	training's auc: 0.999757	valid_1's auc: 0.9191
# [630]	training's auc: 0.999779	valid_1's auc: 0.919248
# [640]	training's auc: 0.999797	valid_1's auc: 0.919295
# [650]	training's auc: 0.999817	valid_1's auc: 0.919498
# [660]	training's auc: 0.999836	valid_1's auc: 0.919667
# [670]	training's auc: 0.999853	valid_1's auc: 0.919847
# [680]	training's auc: 0.99987	valid_1's auc: 0.919936
# [690]	training's auc: 0.999886	valid_1's auc: 0.91997
# [700]	training's auc: 0.999901	valid_1's auc: 0.920074
# [710]	training's auc: 0.999913	valid_1's auc: 0.920242
# [720]	training's auc: 0.999922	valid_1's auc: 0.920221
# [730]	training's auc: 0.99993	valid_1's auc: 0.920365
# [740]	training's auc: 0.999938	valid_1's auc: 0.92048
# [750]	training's auc: 0.999945	valid_1's auc: 0.92061
# [760]	training's auc: 0.999951	valid_1's auc: 0.920655
# [770]	training's auc: 0.999957	valid_1's auc: 0.920741
# [780]	training's auc: 0.999961	valid_1's auc: 0.920689
# [790]	training's auc: 0.999966	valid_1's auc: 0.920775
# [800]	training's auc: 0.99997	valid_1's auc: 0.920877
# [810]	training's auc: 0.999973	valid_1's auc: 0.920879
# [820]	training's auc: 0.999976	valid_1's auc: 0.920979
# [830]	training's auc: 0.999978	valid_1's auc: 0.921079
# [840]	training's auc: 0.999981	valid_1's auc: 0.921078
# [850]	training's auc: 0.999983	valid_1's auc: 0.921177
# [860]	training's auc: 0.999985	valid_1's auc: 0.921257
# [870]	training's auc: 0.999987	valid_1's auc: 0.921359
# [880]	training's auc: 0.999988	valid_1's auc: 0.921462
# [890]	training's auc: 0.99999	valid_1's auc: 0.921453
# [900]	training's auc: 0.999991	valid_1's auc: 0.921523
# [910]	training's auc: 0.999992	valid_1's auc: 0.921654
# [920]	training's auc: 0.999993	valid_1's auc: 0.921696
# [930]	training's auc: 0.999994	valid_1's auc: 0.921847
# [940]	training's auc: 0.999995	valid_1's auc: 0.921958
# [950]	training's auc: 0.999995	valid_1's auc: 0.92205
# [960]	training's auc: 0.999996	valid_1's auc: 0.922132
# [970]	training's auc: 0.999996	valid_1's auc: 0.922208
# [980]	training's auc: 0.999997	valid_1's auc: 0.922286
# [990]	training's auc: 0.999997	valid_1's auc: 0.922259
# [1000]	training's auc: 0.999997	valid_1's auc: 0.922306
# [1010]	training's auc: 0.999998	valid_1's auc: 0.922321
# [1020]	training's auc: 0.999998	valid_1's auc: 0.922368
# [1030]	training's auc: 0.999998	valid_1's auc: 0.922361
# [1040]	training's auc: 0.999999	valid_1's auc: 0.922409
# [1050]	training's auc: 0.999999	valid_1's auc: 0.922405
# [1060]	training's auc: 0.999999	valid_1's auc: 0.92242
# [1070]	training's auc: 0.999999	valid_1's auc: 0.922428
# [1080]	training's auc: 0.999999	valid_1's auc: 0.922456
# [1090]	training's auc: 0.999999	valid_1's auc: 0.922557
# [1100]	training's auc: 0.999999	valid_1's auc: 0.92258
# [1110]	training's auc: 0.999999	valid_1's auc: 0.922633
# [1120]	training's auc: 1	valid_1's auc: 0.922667
# [1130]	training's auc: 1	valid_1's auc: 0.922633
# [1140]	training's auc: 1	valid_1's auc: 0.922732
# [1150]	training's auc: 1	valid_1's auc: 0.922752
# [1160]	training's auc: 1	valid_1's auc: 0.92279
# [1170]	training's auc: 1	valid_1's auc: 0.922846
# [1180]	training's auc: 1	valid_1's auc: 0.922927
# [1190]	training's auc: 1	valid_1's auc: 0.922957
# [1200]	training's auc: 1	valid_1's auc: 0.922926
# [1210]	training's auc: 1	valid_1's auc: 0.922974
# [1220]	training's auc: 1	valid_1's auc: 0.922974
# [1230]	training's auc: 1	valid_1's auc: 0.922891
# [1240]	training's auc: 1	valid_1's auc: 0.922869
# [1250]	training's auc: 1	valid_1's auc: 0.922834
# [1260]	training's auc: 1	valid_1's auc: 0.922798
# [1270]	training's auc: 1	valid_1's auc: 0.922825
# [1280]	training's auc: 1	valid_1's auc: 0.922781
# Early stopping, best iteration is:
# [1188]	training's auc: 1	valid_1's auc: 0.922994
# Fold 1 | AUC: 0.922996088744284
# Fold: 2
# c:\users\oem\appdata\local\programs\python\python37\lib\site-packages\lightgbm\engine.py:123: UserWarning:
#
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.913961	valid_1's auc: 0.882691
# [20]	training's auc: 0.920527	valid_1's auc: 0.887421
# [30]	training's auc: 0.924736	valid_1's auc: 0.890006
# [40]	training's auc: 0.931019	valid_1's auc: 0.893868
# [50]	training's auc: 0.937017	valid_1's auc: 0.897104
# [60]	training's auc: 0.942119	valid_1's auc: 0.899886
# [70]	training's auc: 0.946661	valid_1's auc: 0.901615
# [80]	training's auc: 0.950695	valid_1's auc: 0.903573
# [90]	training's auc: 0.953757	valid_1's auc: 0.904879
# [100]	training's auc: 0.956912	valid_1's auc: 0.906459
# [110]	training's auc: 0.960343	valid_1's auc: 0.90805
# [120]	training's auc: 0.963126	valid_1's auc: 0.909159
# [130]	training's auc: 0.965677	valid_1's auc: 0.910793
# [140]	training's auc: 0.967938	valid_1's auc: 0.911892
# [150]	training's auc: 0.970402	valid_1's auc: 0.913079
# [160]	training's auc: 0.972983	valid_1's auc: 0.914583
# [170]	training's auc: 0.975216	valid_1's auc: 0.915594
# [180]	training's auc: 0.977598	valid_1's auc: 0.917204
# [190]	training's auc: 0.979486	valid_1's auc: 0.918336
# [200]	training's auc: 0.981191	valid_1's auc: 0.919107
# [210]	training's auc: 0.983443	valid_1's auc: 0.920462
# [220]	training's auc: 0.985302	valid_1's auc: 0.921499
# [230]	training's auc: 0.986941	valid_1's auc: 0.922284
# [240]	training's auc: 0.988301	valid_1's auc: 0.92354
# [250]	training's auc: 0.989564	valid_1's auc: 0.924367
# [260]	training's auc: 0.990882	valid_1's auc: 0.925407
# [270]	training's auc: 0.991855	valid_1's auc: 0.92612
# [280]	training's auc: 0.992802	valid_1's auc: 0.926948
# [290]	training's auc: 0.993641	valid_1's auc: 0.927831
# [300]	training's auc: 0.994423	valid_1's auc: 0.928475
# [310]	training's auc: 0.995038	valid_1's auc: 0.92909
# [320]	training's auc: 0.995561	valid_1's auc: 0.929528
# [330]	training's auc: 0.996066	valid_1's auc: 0.930179
# [340]	training's auc: 0.996508	valid_1's auc: 0.930652
# [350]	training's auc: 0.996928	valid_1's auc: 0.930961
# [360]	training's auc: 0.997246	valid_1's auc: 0.931536
# [370]	training's auc: 0.997562	valid_1's auc: 0.931808
# [380]	training's auc: 0.997845	valid_1's auc: 0.932118
# [390]	training's auc: 0.998086	valid_1's auc: 0.932346
# [400]	training's auc: 0.998289	valid_1's auc: 0.932554
# [410]	training's auc: 0.99847	valid_1's auc: 0.93288
# [420]	training's auc: 0.998642	valid_1's auc: 0.933234
# [430]	training's auc: 0.998783	valid_1's auc: 0.933474
# [440]	training's auc: 0.998909	valid_1's auc: 0.933888
# [450]	training's auc: 0.999025	valid_1's auc: 0.934239
# [460]	training's auc: 0.999126	valid_1's auc: 0.934308
# [470]	training's auc: 0.999225	valid_1's auc: 0.934484
# [480]	training's auc: 0.999309	valid_1's auc: 0.934781
# [490]	training's auc: 0.999382	valid_1's auc: 0.934929
# [500]	training's auc: 0.999447	valid_1's auc: 0.935201
# [510]	training's auc: 0.999503	valid_1's auc: 0.935395
# [520]	training's auc: 0.999553	valid_1's auc: 0.935534
# [530]	training's auc: 0.999598	valid_1's auc: 0.935775
# [540]	training's auc: 0.999643	valid_1's auc: 0.935948
# [550]	training's auc: 0.999681	valid_1's auc: 0.935994
# [560]	training's auc: 0.999715	valid_1's auc: 0.936134
# [570]	training's auc: 0.999748	valid_1's auc: 0.936154
# [580]	training's auc: 0.999773	valid_1's auc: 0.936298
# [590]	training's auc: 0.999799	valid_1's auc: 0.936503
# [600]	training's auc: 0.999821	valid_1's auc: 0.936584
# [610]	training's auc: 0.999841	valid_1's auc: 0.93677
# [620]	training's auc: 0.999859	valid_1's auc: 0.936808
# [630]	training's auc: 0.999877	valid_1's auc: 0.936889
# [640]	training's auc: 0.99989	valid_1's auc: 0.936995
# [650]	training's auc: 0.999903	valid_1's auc: 0.937151
# [660]	training's auc: 0.999914	valid_1's auc: 0.937267
# [670]	training's auc: 0.999924	valid_1's auc: 0.937395
# [680]	training's auc: 0.999934	valid_1's auc: 0.937499
# [690]	training's auc: 0.999942	valid_1's auc: 0.937597
# [700]	training's auc: 0.999949	valid_1's auc: 0.93764
# [710]	training's auc: 0.999954	valid_1's auc: 0.93778
# [720]	training's auc: 0.99996	valid_1's auc: 0.937914
# [730]	training's auc: 0.999965	valid_1's auc: 0.93795
# [740]	training's auc: 0.999969	valid_1's auc: 0.938066
# [750]	training's auc: 0.999973	valid_1's auc: 0.938072
# [760]	training's auc: 0.999976	valid_1's auc: 0.938126
# [770]	training's auc: 0.999979	valid_1's auc: 0.938102
# [780]	training's auc: 0.999982	valid_1's auc: 0.938109
# [790]	training's auc: 0.999984	valid_1's auc: 0.938189
# [800]	training's auc: 0.999986	valid_1's auc: 0.938162
# [810]	training's auc: 0.999988	valid_1's auc: 0.938181
# [820]	training's auc: 0.99999	valid_1's auc: 0.938225
# [830]	training's auc: 0.999991	valid_1's auc: 0.938344
# [840]	training's auc: 0.999992	valid_1's auc: 0.938386
# [850]	training's auc: 0.999993	valid_1's auc: 0.93837
# [860]	training's auc: 0.999994	valid_1's auc: 0.93845
# [870]	training's auc: 0.999995	valid_1's auc: 0.938536
# [880]	training's auc: 0.999996	valid_1's auc: 0.938586
# [890]	training's auc: 0.999996	valid_1's auc: 0.938607
# [900]	training's auc: 0.999997	valid_1's auc: 0.938586
# [910]	training's auc: 0.999997	valid_1's auc: 0.938588
# [920]	training's auc: 0.999997	valid_1's auc: 0.938535
# [930]	training's auc: 0.999998	valid_1's auc: 0.938537
# [940]	training's auc: 0.999998	valid_1's auc: 0.938499
# [950]	training's auc: 0.999998	valid_1's auc: 0.938513
# [960]	training's auc: 0.999999	valid_1's auc: 0.938581
# [970]	training's auc: 0.999999	valid_1's auc: 0.938545
# [980]	training's auc: 0.999999	valid_1's auc: 0.938542
# Early stopping, best iteration is:
# [889]	training's auc: 0.999996	valid_1's auc: 0.938614
# Fold 2 | AUC: 0.9386134451237771
# Fold: 3
# c:\users\oem\appdata\local\programs\python\python37\lib\site-packages\lightgbm\engine.py:123: UserWarning:
#
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.914405	valid_1's auc: 0.882983
# [20]	training's auc: 0.921867	valid_1's auc: 0.887306
# [30]	training's auc: 0.926264	valid_1's auc: 0.890228
# [40]	training's auc: 0.932125	valid_1's auc: 0.893596
# [50]	training's auc: 0.938408	valid_1's auc: 0.897353
# [60]	training's auc: 0.94318	valid_1's auc: 0.899999
# [70]	training's auc: 0.947127	valid_1's auc: 0.90205
# [80]	training's auc: 0.950752	valid_1's auc: 0.90402
# [90]	training's auc: 0.954099	valid_1's auc: 0.905481
# [100]	training's auc: 0.957456	valid_1's auc: 0.907329
# [110]	training's auc: 0.96106	valid_1's auc: 0.909559
# [120]	training's auc: 0.963968	valid_1's auc: 0.911223
# [130]	training's auc: 0.966678	valid_1's auc: 0.912905
# [140]	training's auc: 0.968962	valid_1's auc: 0.91444
# [150]	training's auc: 0.971412	valid_1's auc: 0.915281
# [160]	training's auc: 0.97415	valid_1's auc: 0.916748
# [170]	training's auc: 0.976418	valid_1's auc: 0.91769
# [180]	training's auc: 0.978614	valid_1's auc: 0.919228
# [190]	training's auc: 0.980596	valid_1's auc: 0.920372
# [200]	training's auc: 0.982443	valid_1's auc: 0.921126
# [210]	training's auc: 0.984519	valid_1's auc: 0.922493
# [220]	training's auc: 0.986221	valid_1's auc: 0.923316
# [230]	training's auc: 0.987632	valid_1's auc: 0.924381
# [240]	training's auc: 0.989031	valid_1's auc: 0.925084
# [250]	training's auc: 0.990211	valid_1's auc: 0.925981
# [260]	training's auc: 0.99126	valid_1's auc: 0.926615
# [270]	training's auc: 0.992167	valid_1's auc: 0.927042
# [280]	training's auc: 0.993011	valid_1's auc: 0.927649
# [290]	training's auc: 0.993768	valid_1's auc: 0.928386
# [300]	training's auc: 0.994512	valid_1's auc: 0.929212
# [310]	training's auc: 0.99515	valid_1's auc: 0.929664
# [320]	training's auc: 0.995644	valid_1's auc: 0.930119
# [330]	training's auc: 0.996166	valid_1's auc: 0.930803
# [340]	training's auc: 0.996598	valid_1's auc: 0.931351
# [350]	training's auc: 0.996975	valid_1's auc: 0.931819
# [360]	training's auc: 0.997291	valid_1's auc: 0.932032
# [370]	training's auc: 0.997586	valid_1's auc: 0.932228
# [380]	training's auc: 0.997862	valid_1's auc: 0.932546
# [390]	training's auc: 0.998073	valid_1's auc: 0.932902
# [400]	training's auc: 0.998278	valid_1's auc: 0.933168
# [410]	training's auc: 0.998467	valid_1's auc: 0.93329
# [420]	training's auc: 0.99863	valid_1's auc: 0.933474
# [430]	training's auc: 0.99877	valid_1's auc: 0.933745
# [440]	training's auc: 0.998901	valid_1's auc: 0.933904
# [450]	training's auc: 0.999024	valid_1's auc: 0.934083
# [460]	training's auc: 0.999123	valid_1's auc: 0.934239
# [470]	training's auc: 0.99922	valid_1's auc: 0.934396
# [480]	training's auc: 0.9993	valid_1's auc: 0.934419
# [490]	training's auc: 0.999374	valid_1's auc: 0.93469
# [500]	training's auc: 0.999436	valid_1's auc: 0.934943
# [510]	training's auc: 0.999495	valid_1's auc: 0.935061
# [520]	training's auc: 0.999544	valid_1's auc: 0.935156
# [530]	training's auc: 0.99959	valid_1's auc: 0.935217
# [540]	training's auc: 0.999633	valid_1's auc: 0.935361
# [550]	training's auc: 0.99967	valid_1's auc: 0.935472
# [560]	training's auc: 0.999704	valid_1's auc: 0.935556
# [570]	training's auc: 0.999737	valid_1's auc: 0.935603
# [580]	training's auc: 0.999765	valid_1's auc: 0.935739
# [590]	training's auc: 0.99979	valid_1's auc: 0.935817
# [600]	training's auc: 0.999811	valid_1's auc: 0.935945
# [610]	training's auc: 0.999831	valid_1's auc: 0.935975
# [620]	training's auc: 0.999851	valid_1's auc: 0.936093
# [630]	training's auc: 0.999867	valid_1's auc: 0.936153
# [640]	training's auc: 0.999883	valid_1's auc: 0.936139
# [650]	training's auc: 0.999896	valid_1's auc: 0.936274
# [660]	training's auc: 0.999907	valid_1's auc: 0.936302
# [670]	training's auc: 0.999917	valid_1's auc: 0.936304
# [680]	training's auc: 0.999927	valid_1's auc: 0.93642
# [690]	training's auc: 0.999935	valid_1's auc: 0.93652
# [700]	training's auc: 0.999942	valid_1's auc: 0.936545
# [710]	training's auc: 0.999949	valid_1's auc: 0.936509
# [720]	training's auc: 0.999954	valid_1's auc: 0.936557
# [730]	training's auc: 0.999959	valid_1's auc: 0.9365
# [740]	training's auc: 0.999964	valid_1's auc: 0.936564
# [750]	training's auc: 0.999967	valid_1's auc: 0.936607
# [760]	training's auc: 0.999971	valid_1's auc: 0.936543
# [770]	training's auc: 0.999974	valid_1's auc: 0.93664
# [780]	training's auc: 0.999977	valid_1's auc: 0.936651
# [790]	training's auc: 0.999979	valid_1's auc: 0.936703
# [800]	training's auc: 0.999982	valid_1's auc: 0.936774
# [810]	training's auc: 0.999984	valid_1's auc: 0.936768
# [820]	training's auc: 0.999985	valid_1's auc: 0.936845
# [830]	training's auc: 0.999987	valid_1's auc: 0.936838
# [840]	training's auc: 0.999988	valid_1's auc: 0.936811
# [850]	training's auc: 0.999989	valid_1's auc: 0.936908
# [860]	training's auc: 0.99999	valid_1's auc: 0.936951
# [870]	training's auc: 0.999991	valid_1's auc: 0.936988
# [880]	training's auc: 0.999992	valid_1's auc: 0.937042
# [890]	training's auc: 0.999993	valid_1's auc: 0.937067
# [900]	training's auc: 0.999994	valid_1's auc: 0.937047
# [910]	training's auc: 0.999994	valid_1's auc: 0.937118
# [920]	training's auc: 0.999995	valid_1's auc: 0.937082
# [930]	training's auc: 0.999995	valid_1's auc: 0.937086
# [940]	training's auc: 0.999996	valid_1's auc: 0.937145
# [950]	training's auc: 0.999997	valid_1's auc: 0.937099
# [960]	training's auc: 0.999997	valid_1's auc: 0.937109
# [970]	training's auc: 0.999998	valid_1's auc: 0.9371
# [980]	training's auc: 0.999998	valid_1's auc: 0.937135
# [990]	training's auc: 0.999998	valid_1's auc: 0.937086
# [1000]	training's auc: 0.999998	valid_1's auc: 0.937108
# [1010]	training's auc: 0.999999	valid_1's auc: 0.937107
# [1020]	training's auc: 0.999999	valid_1's auc: 0.93708
# [1030]	training's auc: 0.999999	valid_1's auc: 0.937052
# [1040]	training's auc: 0.999999	valid_1's auc: 0.937031
# [1050]	training's auc: 0.999999	valid_1's auc: 0.937004
# [1060]	training's auc: 0.999999	valid_1's auc: 0.937032
# [1070]	training's auc: 0.999999	valid_1's auc: 0.937035
# Early stopping, best iteration is:
# [976]	training's auc: 0.999998	valid_1's auc: 0.937165
# Fold 3 | AUC: 0.9371666503108836
# Fold: 4
# c:\users\oem\appdata\local\programs\python\python37\lib\site-packages\lightgbm\engine.py:123: UserWarning:
#
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.909016	valid_1's auc: 0.897933
# [20]	training's auc: 0.91725	valid_1's auc: 0.902876
# [30]	training's auc: 0.921854	valid_1's auc: 0.905148
# [40]	training's auc: 0.930143	valid_1's auc: 0.910073
# [50]	training's auc: 0.935696	valid_1's auc: 0.912826
# [60]	training's auc: 0.940255	valid_1's auc: 0.914788
# [70]	training's auc: 0.945839	valid_1's auc: 0.918533
# [80]	training's auc: 0.950166	valid_1's auc: 0.920928
# [90]	training's auc: 0.953754	valid_1's auc: 0.922706
# [100]	training's auc: 0.956981	valid_1's auc: 0.924254
# [110]	training's auc: 0.96032	valid_1's auc: 0.925809
# [120]	training's auc: 0.963656	valid_1's auc: 0.926955
# [130]	training's auc: 0.965891	valid_1's auc: 0.928289
# [140]	training's auc: 0.968152	valid_1's auc: 0.929384
# [150]	training's auc: 0.970735	valid_1's auc: 0.930308
# [160]	training's auc: 0.973459	valid_1's auc: 0.931841
# [170]	training's auc: 0.975854	valid_1's auc: 0.933116
# [180]	training's auc: 0.978219	valid_1's auc: 0.93486
# [190]	training's auc: 0.980718	valid_1's auc: 0.936262
# [200]	training's auc: 0.98252	valid_1's auc: 0.937351
# [210]	training's auc: 0.984512	valid_1's auc: 0.938719
# [220]	training's auc: 0.985965	valid_1's auc: 0.939695
# [230]	training's auc: 0.987543	valid_1's auc: 0.940709
# [240]	training's auc: 0.98873	valid_1's auc: 0.941717
# [250]	training's auc: 0.989896	valid_1's auc: 0.942652
# [260]	training's auc: 0.991009	valid_1's auc: 0.94356
# [270]	training's auc: 0.992021	valid_1's auc: 0.944303
# [280]	training's auc: 0.99291	valid_1's auc: 0.945037
# [290]	training's auc: 0.993714	valid_1's auc: 0.945726
# [300]	training's auc: 0.994423	valid_1's auc: 0.946435
# [310]	training's auc: 0.995052	valid_1's auc: 0.946943
# [320]	training's auc: 0.995551	valid_1's auc: 0.947332
# [330]	training's auc: 0.996053	valid_1's auc: 0.947773
# [340]	training's auc: 0.996484	valid_1's auc: 0.948219
# [350]	training's auc: 0.996885	valid_1's auc: 0.948488
# [360]	training's auc: 0.997235	valid_1's auc: 0.948877
# [370]	training's auc: 0.997552	valid_1's auc: 0.949241
# [380]	training's auc: 0.997824	valid_1's auc: 0.949519
# [390]	training's auc: 0.998051	valid_1's auc: 0.949735
# [400]	training's auc: 0.998263	valid_1's auc: 0.950074
# [410]	training's auc: 0.998442	valid_1's auc: 0.950431
# [420]	training's auc: 0.998592	valid_1's auc: 0.95072
# [430]	training's auc: 0.998753	valid_1's auc: 0.951049
# [440]	training's auc: 0.998878	valid_1's auc: 0.951375
# [450]	training's auc: 0.999017	valid_1's auc: 0.951437
# [460]	training's auc: 0.999118	valid_1's auc: 0.951546
# [470]	training's auc: 0.999215	valid_1's auc: 0.951765
# [480]	training's auc: 0.999299	valid_1's auc: 0.951952
# [490]	training's auc: 0.999378	valid_1's auc: 0.95214
# [500]	training's auc: 0.999443	valid_1's auc: 0.952291
# [510]	training's auc: 0.999496	valid_1's auc: 0.952446
# [520]	training's auc: 0.999551	valid_1's auc: 0.952599
# [530]	training's auc: 0.999601	valid_1's auc: 0.952716
# [540]	training's auc: 0.99964	valid_1's auc: 0.95288
# [550]	training's auc: 0.99968	valid_1's auc: 0.952948
# [560]	training's auc: 0.999715	valid_1's auc: 0.95303
# [570]	training's auc: 0.999746	valid_1's auc: 0.95313
# [580]	training's auc: 0.999774	valid_1's auc: 0.953242
# [590]	training's auc: 0.9998	valid_1's auc: 0.953277
# [600]	training's auc: 0.999824	valid_1's auc: 0.953377
# [610]	training's auc: 0.999842	valid_1's auc: 0.953414
# [620]	training's auc: 0.999862	valid_1's auc: 0.953398
# [630]	training's auc: 0.999877	valid_1's auc: 0.953427
# [640]	training's auc: 0.999891	valid_1's auc: 0.953497
# [650]	training's auc: 0.999904	valid_1's auc: 0.953499
# [660]	training's auc: 0.999915	valid_1's auc: 0.953541
# [670]	training's auc: 0.999925	valid_1's auc: 0.953596
# [680]	training's auc: 0.999934	valid_1's auc: 0.95373
# [690]	training's auc: 0.999941	valid_1's auc: 0.953769
# [700]	training's auc: 0.999948	valid_1's auc: 0.953845
# [710]	training's auc: 0.999954	valid_1's auc: 0.953875
# [720]	training's auc: 0.999959	valid_1's auc: 0.95395
# [730]	training's auc: 0.999964	valid_1's auc: 0.953937
# [740]	training's auc: 0.999969	valid_1's auc: 0.953951
# [750]	training's auc: 0.999972	valid_1's auc: 0.953962
# [760]	training's auc: 0.999976	valid_1's auc: 0.953984
# [770]	training's auc: 0.999979	valid_1's auc: 0.954011
# [780]	training's auc: 0.999981	valid_1's auc: 0.954035
# [790]	training's auc: 0.999984	valid_1's auc: 0.954044
# [800]	training's auc: 0.999986	valid_1's auc: 0.954059
# [810]	training's auc: 0.999988	valid_1's auc: 0.954066
# [820]	training's auc: 0.999989	valid_1's auc: 0.954089
# [830]	training's auc: 0.999991	valid_1's auc: 0.954086
# [840]	training's auc: 0.999992	valid_1's auc: 0.954153
# [850]	training's auc: 0.999993	valid_1's auc: 0.954194
# [860]	training's auc: 0.999994	valid_1's auc: 0.954212
# [870]	training's auc: 0.999994	valid_1's auc: 0.954238
# [880]	training's auc: 0.999995	valid_1's auc: 0.954219
# [890]	training's auc: 0.999995	valid_1's auc: 0.954219
# [900]	training's auc: 0.999996	valid_1's auc: 0.954247
# [910]	training's auc: 0.999996	valid_1's auc: 0.954253
# [920]	training's auc: 0.999997	valid_1's auc: 0.954214
# [930]	training's auc: 0.999997	valid_1's auc: 0.954246
# [940]	training's auc: 0.999998	valid_1's auc: 0.954278
# [950]	training's auc: 0.999998	valid_1's auc: 0.954234
# [960]	training's auc: 0.999998	valid_1's auc: 0.954258
# [970]	training's auc: 0.999998	valid_1's auc: 0.954247
# [980]	training's auc: 0.999999	valid_1's auc: 0.954195
# [990]	training's auc: 0.999999	valid_1's auc: 0.954193
# [1000]	training's auc: 0.999999	valid_1's auc: 0.954177
# [1010]	training's auc: 0.999999	valid_1's auc: 0.954192
# [1020]	training's auc: 0.999999	valid_1's auc: 0.954225
# [1030]	training's auc: 0.999999	valid_1's auc: 0.954241
# [1040]	training's auc: 0.999999	valid_1's auc: 0.95425
# Early stopping, best iteration is:
# [940]	training's auc: 0.999998	valid_1's auc: 0.954278
# Fold 4 | AUC: 0.9542780031424903
# Fold: 5
# c:\users\oem\appdata\local\programs\python\python37\lib\site-packages\lightgbm\engine.py:123: UserWarning:
#
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.913776	valid_1's auc: 0.868036
# [20]	training's auc: 0.92092	valid_1's auc: 0.876297
# [30]	training's auc: 0.924461	valid_1's auc: 0.879888
# [40]	training's auc: 0.932527	valid_1's auc: 0.885925
# [50]	training's auc: 0.937818	valid_1's auc: 0.889084
# [60]	training's auc: 0.941201	valid_1's auc: 0.890654
# [70]	training's auc: 0.945871	valid_1's auc: 0.893222
# [80]	training's auc: 0.950305	valid_1's auc: 0.895379
# [90]	training's auc: 0.953885	valid_1's auc: 0.897115
# [100]	training's auc: 0.956882	valid_1's auc: 0.898521
# [110]	training's auc: 0.960011	valid_1's auc: 0.899903
# [120]	training's auc: 0.963129	valid_1's auc: 0.901407
# [130]	training's auc: 0.965794	valid_1's auc: 0.902919
# [140]	training's auc: 0.968344	valid_1's auc: 0.90425
# [150]	training's auc: 0.971059	valid_1's auc: 0.905357
# [160]	training's auc: 0.97376	valid_1's auc: 0.906556
# [170]	training's auc: 0.97549	valid_1's auc: 0.907731
# [180]	training's auc: 0.977711	valid_1's auc: 0.908967
# [190]	training's auc: 0.980336	valid_1's auc: 0.910645
# [200]	training's auc: 0.982163	valid_1's auc: 0.911637
# [210]	training's auc: 0.983983	valid_1's auc: 0.912611
# [220]	training's auc: 0.98561	valid_1's auc: 0.913893
# [230]	training's auc: 0.987249	valid_1's auc: 0.915032
# [240]	training's auc: 0.988789	valid_1's auc: 0.916046
# [250]	training's auc: 0.989982	valid_1's auc: 0.916839
# [260]	training's auc: 0.990993	valid_1's auc: 0.917927
# [270]	training's auc: 0.991903	valid_1's auc: 0.918988
# [280]	training's auc: 0.992732	valid_1's auc: 0.919466
# [290]	training's auc: 0.993535	valid_1's auc: 0.920348
# [300]	training's auc: 0.994341	valid_1's auc: 0.920955
# [310]	training's auc: 0.994963	valid_1's auc: 0.921549
# [320]	training's auc: 0.995446	valid_1's auc: 0.922083
# [330]	training's auc: 0.995946	valid_1's auc: 0.922516
# [340]	training's auc: 0.996429	valid_1's auc: 0.923093
# [350]	training's auc: 0.996802	valid_1's auc: 0.923708
# [360]	training's auc: 0.997166	valid_1's auc: 0.924202
# [370]	training's auc: 0.997453	valid_1's auc: 0.924709
# [380]	training's auc: 0.997743	valid_1's auc: 0.92517
# [390]	training's auc: 0.997992	valid_1's auc: 0.92565
# [400]	training's auc: 0.998207	valid_1's auc: 0.926115
# [410]	training's auc: 0.998387	valid_1's auc: 0.926572
# [420]	training's auc: 0.998558	valid_1's auc: 0.926842
# [430]	training's auc: 0.998717	valid_1's auc: 0.927304
# [440]	training's auc: 0.99885	valid_1's auc: 0.927629
# [450]	training's auc: 0.998979	valid_1's auc: 0.9278
# [460]	training's auc: 0.999083	valid_1's auc: 0.928195
# [470]	training's auc: 0.999185	valid_1's auc: 0.928472
# [480]	training's auc: 0.999267	valid_1's auc: 0.928644
# [490]	training's auc: 0.999348	valid_1's auc: 0.928784
# [500]	training's auc: 0.999414	valid_1's auc: 0.929062
# [510]	training's auc: 0.999476	valid_1's auc: 0.929116
# [520]	training's auc: 0.999532	valid_1's auc: 0.929282
# [530]	training's auc: 0.999582	valid_1's auc: 0.929331
# [540]	training's auc: 0.999622	valid_1's auc: 0.929472
# [550]	training's auc: 0.999666	valid_1's auc: 0.929664
# [560]	training's auc: 0.999703	valid_1's auc: 0.929786
# [570]	training's auc: 0.999733	valid_1's auc: 0.929959
# [580]	training's auc: 0.999762	valid_1's auc: 0.929993
# [590]	training's auc: 0.999786	valid_1's auc: 0.930099
# [600]	training's auc: 0.99981	valid_1's auc: 0.930118
# [610]	training's auc: 0.99983	valid_1's auc: 0.930247
# [620]	training's auc: 0.999849	valid_1's auc: 0.930376
# [630]	training's auc: 0.999865	valid_1's auc: 0.930389
# [640]	training's auc: 0.999881	valid_1's auc: 0.93045
# [650]	training's auc: 0.999894	valid_1's auc: 0.930547
# [660]	training's auc: 0.999906	valid_1's auc: 0.930658
# [670]	training's auc: 0.999916	valid_1's auc: 0.930723
# [680]	training's auc: 0.999926	valid_1's auc: 0.930763
# [690]	training's auc: 0.999934	valid_1's auc: 0.930756
# [700]	training's auc: 0.999941	valid_1's auc: 0.930865
# [710]	training's auc: 0.999948	valid_1's auc: 0.930965
# [720]	training's auc: 0.999953	valid_1's auc: 0.931006
# [730]	training's auc: 0.999959	valid_1's auc: 0.931165
# [740]	training's auc: 0.999964	valid_1's auc: 0.931268
# [750]	training's auc: 0.999968	valid_1's auc: 0.931227
# [760]	training's auc: 0.999971	valid_1's auc: 0.931249
# [770]	training's auc: 0.999975	valid_1's auc: 0.931275
# [780]	training's auc: 0.999978	valid_1's auc: 0.931409
# [790]	training's auc: 0.99998	valid_1's auc: 0.931478
# [800]	training's auc: 0.999983	valid_1's auc: 0.931514
# [810]	training's auc: 0.999984	valid_1's auc: 0.931489
# [820]	training's auc: 0.999986	valid_1's auc: 0.931537
# [830]	training's auc: 0.999988	valid_1's auc: 0.931591
# [840]	training's auc: 0.99999	valid_1's auc: 0.931654
# [850]	training's auc: 0.999991	valid_1's auc: 0.931714
# [860]	training's auc: 0.999992	valid_1's auc: 0.931757
# [870]	training's auc: 0.999993	valid_1's auc: 0.931703
# [880]	training's auc: 0.999994	valid_1's auc: 0.931741
# [890]	training's auc: 0.999994	valid_1's auc: 0.931791
# [900]	training's auc: 0.999995	valid_1's auc: 0.93181
# [910]	training's auc: 0.999995	valid_1's auc: 0.931791
# [920]	training's auc: 0.999996	valid_1's auc: 0.931811
# [930]	training's auc: 0.999997	valid_1's auc: 0.931883
# [940]	training's auc: 0.999997	valid_1's auc: 0.932012
# [950]	training's auc: 0.999998	valid_1's auc: 0.932049
# [960]	training's auc: 0.999998	valid_1's auc: 0.932068
# [970]	training's auc: 0.999998	valid_1's auc: 0.932075
# [980]	training's auc: 0.999999	valid_1's auc: 0.932117
# [990]	training's auc: 0.999999	valid_1's auc: 0.932207
# [1000]	training's auc: 0.999999	valid_1's auc: 0.932192
# [1010]	training's auc: 0.999999	valid_1's auc: 0.93223
# [1020]	training's auc: 0.999999	valid_1's auc: 0.932214
# [1030]	training's auc: 0.999999	valid_1's auc: 0.932193
# [1040]	training's auc: 0.999999	valid_1's auc: 0.932206
# [1050]	training's auc: 1	valid_1's auc: 0.932203
# [1060]	training's auc: 1	valid_1's auc: 0.932203
# [1070]	training's auc: 1	valid_1's auc: 0.932272
# [1080]	training's auc: 1	valid_1's auc: 0.93225
# [1090]	training's auc: 1	valid_1's auc: 0.932192
# [1100]	training's auc: 1	valid_1's auc: 0.932153
# [1110]	training's auc: 1	valid_1's auc: 0.932088
# [1120]	training's auc: 1	valid_1's auc: 0.932049
# [1130]	training's auc: 1	valid_1's auc: 0.932057
# [1140]	training's auc: 1	valid_1's auc: 0.932011
# [1150]	training's auc: 1	valid_1's auc: 0.932035
# [1160]	training's auc: 1	valid_1's auc: 0.932105
# [1170]	training's auc: 1	valid_1's auc: 0.93217
# Early stopping, best iteration is:
# [1070]	training's auc: 1	valid_1's auc: 0.932272
# Fold 5 | AUC: 0.9322696251957734
#
# Mean AUC = 0.9370647625034417
# Out of folds AUC = 0.9378785753461603

# %%
##trick here 
##for oof = 0.93547, LB score is 0.9458
##for oof = 0.936, LB score is 0.945

# %%
import matplotlib.pyplot as plt
import seaborn as sns
##take the mean of each feature importance of all folds. 
feature_importances['average'] = feature_importances[[f'fold_{fold_n + 1}' for fold_n in range(folds.n_splits)]].mean(axis=1)

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importances.sort_values(by='average', ascending=False).head(50), x='average', y='feature');
plt.title('50 TOP feature importance over {} folds average'.format(folds.n_splits));

# %%
sub = pd.DataFrame(columns=['TransactionID','isFraud'])
sub['TransactionID'] = X_test.index
sub['isFraud'] = y_result
sub




sub.to_csv("submission58th-1.csv",index=False)

sum(y_result>0.1)
# Out:
# 15469

# %%
sum(y_result>0.5)
# Out:
# 7763
